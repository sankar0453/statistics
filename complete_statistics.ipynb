# %%
data=[23,24,32,45,12,43,67,45,32,56,32]
data
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
data_copy= data
data_copy
# Out:
# [23, 24, 32, 45, 12, 43, 67, 45, 32, 56, 32]

# %%
import seaborn as sns

sns.histplot(data_copy,kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
data_copy.sort()
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67]

# %%
data_copy.append(179)
data_copy.append(210)
data_copy.append(290)
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
import seaborn as sns

sns.histplot(data_copy,kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
data
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
# It is right skewed data
data_copy
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
data_copy2=data
data_copy2
# Out:
# [12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290, 179]

# %%
data_copy2.insert(0,-10)

# %%
data_copy2
# Out:
# [-10, -10, 12, 23, 24, 32, 32, 32, 43, 45, 45, 56, 67, 179, 210, 290]

# %%
sns.histplot(data_copy2,kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
import pandas as pd
data2=pd.read_csv("data/iris.csv")
data2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.histplot(data2["sepal_length"],kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
sns.histplot(data2["sepal_width"],kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
sns.histplot(data2["petal_length"],kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='petal_length', ylabel='Count'>

# %%
# it follws normal distriution but it has outliers at left skew
# it is also a biomodel

# %%
sns.histplot(data2["petal_width"],kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='petal_width', ylabel='Count'>

# %% [markdown]
# probability disrtribution function
# ----------------------------------
#
# probabilty mass function (Discrete Probability Distribution)
# - uniform
# - bernouli
# - binomial dist
# - possion
#
# prprobabilty density function(Continues Probability Distribution)
# - uniform
# - normal(SND)
# - lognormal
# - power law
# - pareto

# %%
import numpy as np
mu=0.5
sigma=0.2
normal_distributed_data=np.random.normal(mu,sigma,1000)

# %%
normal_distributed_data
# Out:
#         0.85183929,  0.83706928,  0.403887  ,  0.54162188,  0.38525745,
#         0.37083358,  0.67091281,  0.53323007,  0.43638369,  0.54115197,
#         0.42473958,  0.7311904 ,  0.29035768,  0.32529532,  0.79557478,
#         0.13879904,  0.27613068,  0.22107939,  0.62915254,  0.05195512])

# %%
sns.histplot(normal_distributed_data,kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %% [markdown]
# ### In probability theory, a log-normal (or lognormal) distribution is a continuous probability distribution of a random variable whose logarithm is normally distributed. Thus, if the random variable X is log-normally distributed, then Y = ln(X) has a normal distribution.Equivalently, if Y has a normal distribution, then the exponential function of Y, X = exp(Y), has a log-normal distribution.

# %%
mu=3.0
sigma=1.0
lognormal_distributed_data=np.random.lognormal(mu,sigma,1000)

# %%
sns.histplot(lognormal_distributed_data,kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
sns.histplot(np.log(lognormal_distributed_data),kde=True)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %% [markdown]
# QQ plots

# %%
import matplotlib.pyplot as plt
import scipy.stats as stat
import pylab

def plot_data(data):
    plt.figure(figsize=(10,6))
    plt.subplot(1,2,1)
    sns.histplot(data,kde=True)
    plt.subplot(1,2,2)
    stat.probplot(data,dist='norm',plot=pylab)
    plt.show()

# %%
plot_data(lognormal_distributed_data)
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plot_data(np.log(lognormal_distributed_data))
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Probability distributin functions
# Probability Mass function (Descrete):
    # -Uniform
    # -Bernouli
    # -Binomial
    # -Possion
# Probability Dense function (Contineous)
    # - Uniform
    # Normal(Standard)
    # lognormal
    # power law 
    # pareto

# %%
np.random.uniform(size=500)
# Out:
# array([0.02735213, 0.24223307, 0.09885544, 0.13003957, 0.68840337,
#        0.91897148, 0.43365247, 0.86613726, 0.13793393, 0.86412011,
#        0.11145412, 0.64542847, 0.107425  , 0.43298422, 0.63119616,
#        0.75262869, 0.26590537, 0.95525341, 0.45009388, 0.82113516,
#        0.7191708 , 0.07382695, 0.68886428, 0.26322673, 0.90336601,
#        0.10044874, 0.14793051, 0.3950742 , 0.9343266 , 0.36143957,
#        0.15221038, 0.47670488, 0.57896288, 0.5032628 , 0.30033579,
#        0.00111479, 0.97893008, 0.13739369, 0.83707087, 0.69338479,
#        0.74387812, 0.33980435, 0.72244198, 0.56078048, 0.94431162,
#        0.22535534, 0.95825313, 0.34317098, 0.14803013, 0.2079875 ,
#        0.9175042 , 0.37682624, 0.65555114, 0.45779554, 0.83390722,
#        0.33081016, 0.46714915, 0.32794686, 0.78135693, 0.75650738,
#        0.85805358, 0.93502074, 0.0329674 , 0.02583773, 0.59839446,
#        0.97749011, 0.89607377, 0.59700311, 0.05123939, 0.37815487,
#        0.48174495, 0.48491449, 0.35880334, 0.05924221, 0.50876715,
#        0.64425414, 0.38601174, 0.78622588, 0.71379652, 0.0116045 ,
#        0.27651712, 0.45278621, 0.50408341, 0.701108  , 0.13849495,
#        0.24459899, 0.45987712, 0.14511248, 0.08896736, 0.30183036,
#        0.39102495, 0.61084391, 0.16459797, 0.23041519, 0.73603378,
#        0.52044254, 0.48071462, 0.60655551, 0.87007075, 0.87638679,
#        0.23686773, 0.59991868, 0.32605949, 0.16185165, 0.77269343])

# %%
from numpy import random
sns.distplot(random.uniform(size=500),hist=False)
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_25388\1536674721.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=500),hist=False)
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
sns.histplot(np.random.randint(1,8,size=800))
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
p=0.3
sample_size=1000

bernouli_data=np.random.choice([0,1],size=sample_size,p=[1-p,p])

sns.histplot(bernouli_data,bins=2,kde=False,color="blue")
# Out:
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Count'>

# %%
no_of_trials=10
probaility=0.6

data3=np.random.binomial(no_of_trials,probaility,10000)

# %%
sns.distplot(data3)
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_25388\2956261776.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data3)
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
poisson_data = np.random.poisson(lam=5, size=1000)
 
# plotting a histogram
ax = sns.distplot(poisson_data,
                  kde=False,
                  color='blue')
ax.set(xlabel='Poisson Distribution', ylabel='Frequency')
 
plt.show()
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_25388\2992645912.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(poisson_data,

# %% [markdown]
# Central limit therom
#
# **Suppose you have a population with any shape of probability distribution (not necessarily normal), and you draw random samples of a fixed size from this population. As the sample size increases, the distribution of the sample means approaches a normal distribution, regardless of the shape of the original population distribution.**

# %%
population=np.random.randint(10,20,50)
population
# Out:
# array([16, 18, 18, 13, 10, 18, 10, 19, 19, 13, 15, 10, 10, 10, 18, 19, 10,
#        14, 19, 11, 10, 11, 10, 17, 13, 19, 18, 19, 15, 13, 16, 13, 12, 19,
#        16, 11, 11, 16, 17, 17, 11, 18, 16, 18, 17, 18, 12, 16, 17, 10])

# %%
np.mean(population)
# Out:
# 14.9

# %%
np.median(population)
# Out:
# 15.0

# %%
from statistics import mode
mode(population)
# Out:
# 15

# %%
#random sample form the population
sample=np.random.choice(population,20)
sample
# Out:
# array([19, 15, 19, 15, 15, 12, 19, 13, 14, 11, 18, 12, 14, 15, 18, 13, 16,
#        15, 14, 10])

# %%
print(f"mean of the sample {np.mean(sample)}")
print(f"medien of the sample {np.median(sample)}")
print(f"mode of the sample {mode(sample)}")
# Out:
# mean of the sample 14.85
# medien of the sample 15.0
# mode of the sample 15

# %%
sample1=np.random.choice(population,20)
sample2=np.random.choice(population,20)
sample3=np.random.choice(population,20)
sample4=np.random.choice(population,20)

# %%
print(sample1)
print(60*"=")
print(sample2)
print(60*"=")
print(sample3)
print(60*"=")
print(sample4)
# Out:
# [19 15 15 14 13 10 18 13 16 12 17 13 10 13 18 10 15 13 14 18]
# ============================================================
# [14 18 10 15 13 14 16 18 12 19 18 14 18 13 19 10 14 12 17 17]
# ============================================================
# [13 19 16 16 18 15 18 16 10 15 12 19 18 18 17 15 17 17 15 15]
# ============================================================
# [10 11 10 16 13 10 14 19 10 18 13 16 12 18 13 19 18 15 12 14]

# %%
mnean_of_the_sample=[]

all_sample=[sample1,sample2,sample3,sample4]

for sample in all_sample:
    print(np.mean(sample))
    mnean_of_the_sample.append(np.mean(sample))
# Out:
# 14.3
# 15.05
# 15.95
# 14.05

# %%
mnean_of_the_sample
# Out:
# [14.3, 15.05, 15.95, 14.05]

# %%
population=np.random.lognormal(3.0,1.0,1000)

# %%
sns.distplot(population)
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_25388\2958836585.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(population)
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %% [markdown]
# Suppose you have a population with any shape of probability distribution (not necessarily normal), and you draw random samples**(at least 30)** of a fixed size(in our case i took 3000 initially) from this population. As the sample size increases**(it might be anything and take as much as data)**, the distribution of the sample means approaches a normal distribution, regardless of the shape of the original population distribution.

# %%
len(population)
# Out:
# 1000

# %%
size=int(len(population)*0.30)
print(size)
# Out:
# 300

# %%
sample_mean=[]

for i in range(1,31):
    sample=np.random.choice(population,size=size)
    sample_mean.append(np.mean(sample))

# %%
sample_mean
# Out:
# [28.781673418861647,
#  31.340905747312064,
#  29.844410883724656,
#  29.76946072583002,
#  31.838701771968804,
#  32.12933382605336,
#  30.480225820529885,
#  31.249549026948262,
#  32.053126838726044,
#  32.608918697260236,
#  35.66546475407049,
#  32.71725581674534,
#  37.42273218005966,
#  34.427551929797495,
#  31.13716490848909,
#  32.882995698532916,
#  31.493014324579107,
#  27.042197756430983,
#  34.25021316288267,
#  32.19015228737534,
#  33.09634448649486,
#  31.257676138839052,
#  35.107808624470906,
#  29.728100140183095,
#  35.08066458359248,
#  35.52827593388236,
#  32.78207933825533,
#  31.568377250742525,
#  31.132738242199704,
#  30.322608175046227]

# %%
sns.distplot(sample_mean)
# Out:
# C:\Users\sanka\AppData\Local\Temp\ipykernel_25388\514007480.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample_mean)
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Datascience_workspace_2023\statistics\venv\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>
